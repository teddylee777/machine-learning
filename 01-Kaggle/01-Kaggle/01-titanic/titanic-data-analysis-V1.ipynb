# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import numpy as np

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
gender_submission = pd.read_csv('data/gender_submission.csv')

# %%
all_data = pd.concat([train, test], sort=False).reset_index(drop=True)

# %%
print(all_data.shape)
all_data.head()
# Out:
# (1309, 12)
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import seaborn as sns

# %%
all_data['Fare'].fillna(0, inplace=True)

# %%
fig, ax =plt.figure()
fig.set_size_inches(12, 9)
sns.relplot(x='PassengerId', y='Fare', data=all_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-b79a9d91d9a9> in <module>
# ----> 1 fig, ax =plt.figure()
#       2 fig.set_size_inches(12, 9)
#       3 sns.relplot(x='PassengerId', y='Fare', data=all_data)
#
# TypeError: cannot unpack non-iterable Figure object

# %%
fig, ax =plt.subplots(figsize=(12, 9))
sns.relplot(x='PassengerId', y='Fare', data=all_data, ax=ax)

# %%
plt.figure(figsize=(12, 9))
