# %% [markdown]
# ## print (출력)

# %% [markdown]
# - 첫 단원에서는 **기본 print() 의 출력**만 배웁니다.
# - 향후 실습 진행을 위한 정도만 배우고, 나중에 문자열 포맷팅에서 더 자세히 다룹니다.

# %%
print('오늘 파이썬 배우기 좋은 날이네!')
# Out:
# 오늘 파이썬 배우기 좋은 날이네!

# %% [markdown]
# **Jupyter Notebook** 셀에서 맨 끝에 위치한 변수, 문자열, 숫자등은 자동으로 출력합니다.
#
# 3.14, '안녕', 100 이렇게 3개의 값이 있지만, 항상 가장 마지막만 출력됩니다.`ㅡ

# %%
3.14
'안녕'
100
# Out:
# 100

# %% [markdown]
# ## 변수 (Variable)

# %% [markdown]
# 변수는 **데이터를 담는 그릇**이라고 생각하시면 됩니다.
#
# 변수라는 그릇에 정수를 담을 수도 있고, 긴 글을 담을 수도 있고, file을 담을 수도 있습니다. 우리가 재사용 하기 쉽게 **별명**을 지정해 줬다라고 쉽게 생각하시기 바랍니다.

# %% [markdown]
# ### 변수의 이름 규칙 (Rule)
#
# 다음의 **문자만 사용**할 수 있습니다.
# - 소문자(a~z)
# - 대문자(A~Z)
# - 숫자(0~9)
# - 한글도 가능
# - 특수기호는 언더바(_) 만 허용
#
# 다음의 **규칙**을 가집니다.
# - 대소 문자를 구분합니다.
# - 숫자는 맨 처음에 올 수 없습니다.
# - 예약어(keyword)는 사용할 수 없습니다. (def, if, del, import, return 등등)

# %% [markdown]
# case 1. 알파벳 (가능) / 대소문자 모두 가능 /심지어 **한글도 가능하나 사용하는 것은 비추**!

# %%
a = 1

# %%
A = 1

# %%
변수 = 1

# %%
변수
# Out:
# 1

# %% [markdown]
# case 2. 알파벳 + 숫자 (가능)

# %%
a1 = 1

# %% [markdown]
# case 3. 알파벳 + 언더바(_) (가능)

# %%
a_ = 1

# %% [markdown]
# case 4. 언더바(_) + 알파벳 (가능))

# %%
_a = 1

# %% [markdown]
# case 5. 숫자 + 알파벳 (불가능)

# %%
1a = 1
# Out:
#   File "/tmp/ipykernel_665993/1364191551.py", line 1
#     1a = 1
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# case 6. 특수문자 (불가능)

# %%
* = 7
# Out:
#   File "/tmp/ipykernel_665993/1040641717.py", line 1
#     * = 7
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# case 7. 언더바를 제외한 특수문자 (불가능)

# %%
a$ = 6
# Out:
#   File "/tmp/ipykernel_665993/158779158.py", line 1
#     a$ = 6
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# case 8. 변수의 이름 사이의 공백 (불가능)

# %%
a b = 6
# Out:
#   File "/tmp/ipykernel_665993/3277752647.py", line 1
#     a b = 6
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# 주로 변수는 **소문자 알파벳으로 생성**하고, 필요시 **언더바**나 **숫자를 붙히는 방식**이 일반적입니다.

# %%
test = 10

# %%
test01 = 20

# %%
test_01 = 30

# %% [markdown]
# ## 데이터 타입 (Data Type)
#
# 자료형태(자료형), 자료구조라고도 불리웁니다.

# %% [markdown]
# **주요 데이터 타입(type)**
#
# 1. `int` (정수): Integer(정수)의 약어이며, 정수를 나타내는 자료형입니다.
# 2. `float` (실수): Floating point의 약어이며, 소수점이 있는 숫자를 나타내는 자료형입니다.
# 3. `str` (문자열): 문자를 나타내는 자료형입니다. 작은 따옴표 혹은 큰 따옴표로 감싸져 있습니다.
# 4. `bool` (참/거짓): 참 또는 거짓을 나타내는 자료형입니다. True, False에서 T와 F는 반드시 대문자로 표기해야 합니다.

# %% [markdown]
# ### type()

# %% [markdown]
# type 함수를 활용하여 데이터의 타입을 알아 볼 수 있습니다.

# %%
type(1)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
type("안녕")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## int (정수)
#
# Integer(정수)의 약어이며, 정수를 나타내는 자료형입니다.

# %%
a = 1

# %%
print(a)
# Out:
# 1

# %% [markdown]
# **type 확인**

# %%
type(a)
# Out:
# int

# %% [markdown]
# ## float (실수)
#
# Floating point의 약어이며, 소수점이 있는 숫자를 나타내는 자료형입니다.

# %%
a = 3.14

# %%
print(a)
# Out:
# 3.14

# %% [markdown]
# **type 확인**

# %%
type(a)
# Out:
# float

# %% [markdown]
# ## str (문자열)
#
# 문자를 나타내는 자료형입니다. **작은 따옴표** 혹은 **큰 따옴표**로 감싸져 있습니다.

# %% [markdown]
# **작은 따옴표 '  '** 사이에 문자를 입력한 경우

# %%
word = '안녕하세요'

# %%
word
# Out:
# '안녕하세요'

# %% [markdown]
# **type 확인**

# %%
type(word)
# Out:
# str

# %% [markdown]
# **큰 따옴표 "  "** 사이에 문자를 입력한 경우

# %%
word = "안녕하세요"

# %%
word
# Out:
# '안녕하세요'

# %% [markdown]
# ## bool (참/거짓)
#
# 참 또는 거짓을 나타내는 자료형입니다. True, False에서 T와 F는 **반드시 대문자로 표기**해야 합니다.

# %%
a = False

# %%
print(a)
# Out:
# False

# %% [markdown]
# **type 확인**

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ## 아무것도 아닌 None 타입

# %% [markdown]
# 말 그래도 아무 것도 아닌 흔히 Null 값을 넣는다고도 합니다.
#
# 사전상 의미는<br>
# * **Null: Nullify (무효화하다)**
# 라는 뜻을 가지고 있다네요~
#
# python에서는 **None** 입니다!

# %%
a = None

# %% [markdown]
# **type 확인**

# %%
type(a)
# Out:
# NoneType

# %%
print(a)
# Out:
# None

# %% [markdown]
# # 타입 변환

# %% [markdown]
# `int`를 `float`로 변환한 경우

# %%
a = 1

# %%
type(a)
# Out:
# int

# %%
float(a)
# Out:
# 1.0

# %% [markdown]
# `float`를 `int`로 변환한 경우
#
# - float를 int로 변환시 반올림이 아닌 값이 버림되어 집니다. (소수점 이하 절삭)

# %%
b = 3.99

# %%
int(b)
# Out:
# 3

# %% [markdown]
# `bool`을 `int`로 변환한 경우

# %%
c = True

# %%
int(c)
# Out:
# 1

# %%
d = False

# %%
int(d)
# Out:
# 0

# %% [markdown]
# `bool`을 `float`로 변환한 경우

# %%
float(True)
# Out:
# 1.0

# %% [markdown]
# ## 연습문제

# %% [markdown]
# 다음과 같이 출력 되도록 코드를 작성하세요

# %% [markdown]
# ### Q1: Type 확인

# %%
a = 3.14

# %% [markdown]
# 타입을 확인해 주세요

# %%
# 코드를 입력해 주세요
type(a)
# Out:
# float

# %% [markdown]
# ### Q2: Type 변경

# %%
a = 1

# %% [markdown]
# 타입을 변경해 주세요

# %%
# 코드를 입력해 주세요
float(a)
# Out:
# 1.0

# %% [markdown]
# ### Q3: Type 변경

# %%
a = 1

# %% [markdown]
# 타입을 변경해 주세요

# %%
# 코드를 입력해 주세요
bool(a)
# Out:
# True

# %% [markdown]
# ### Q4: 타입 변경

# %%
a = False

# %% [markdown]
# 타입을 변경해 주세요

# %%
# 코드를 입력해 주세요
int(a)
# Out:
# 0

# %% [markdown]
# ### Q5: 타입 변경

# %%
a = 123

# %% [markdown]
# 타입을 변경해 주세요

# %%
# 코드를 입력해 주세요
str(a)
# Out:
# '123'
