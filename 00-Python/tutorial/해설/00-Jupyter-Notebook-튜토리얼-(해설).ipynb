# %% [markdown]
# ## python 버젼

# %%
# !python --version
# Out:
# Python 3.6.9

# %% [markdown]
# ## 커멘드 모드 (커서)

# %% [markdown]
# - 커서가 "초록색"은 **입력 모드**
# - 커서가 "파란색"은 **커멘드 모드** 입니다.

# %% [markdown]
# 커멘드 모드에서는 셀의 추가, 삭제 등의 명령을 실행할 수 있습니다.
#
# Esc를 눌러 커서의 색깔을 파란색으로 변경할 수 있습니다.

# %% [markdown]
# ## 셀의 종류 (코드/텍스트)

# %% [markdown]
# 코드 셀: 코드 실행을 위한 셀

# %% [markdown]
# 텍스트 셀: 주석을 달거나, 설명 문구등을 달기 위한 텍스트 전용 셀

# %% [markdown]
# ### 주석과 텍스트 셀의 차이

# %% [markdown]
# 코드셀 설명입니다.

# %%
print('안녕하세요')
# Out:
# 안녕하세요

# %%
# 이렇게 주석을 달 수 있습니다.
print('안녕하세요')
# Out:
# 안녕하세요

# %% [markdown]
# 이것은 텍스트 셀입니다

# %%
# 주석입니다.
print('안녕하세요')

# 주석입니다.
print('안녕하세요')
# Out:
# 안녕하세요
# 안녕하세요

# %% [markdown]
# ### 셀의 삽입(추가)

# %% [markdown]
# 상단의 "Insert" - "Insert Cell Above" 혹은 "Insert Cell Below"를 눌러서 삽입합니다

# %% [markdown]
# **[셀 추가 관련 단축키]**
#
# 1. 코드 셀 위에 삽입 (커멘드 모드 + A)
# 2. 코드 셀 아래에 삽입 (커멘드 모드 + B)

# %% [markdown]
# ### 셀의 삭제

# %% [markdown]
# 우측의 **휴지통 아이콘을 클릭**하여 삭제합니다.

# %% [markdown]
# **[셀 삭제 관련 단축키]**

# %% [markdown]
# 셀 지우기 (커멘드모드 + DD)

# %% [markdown]
# (셀을 삭제해 보세요)

# %% [markdown]
# (셀을 삭제해 보세요)

# %% [markdown]
# (셀을 삭제해 보세요)

# %% [markdown]
# ### 실행 취소

# %% [markdown]
# 잘못 삭제한 경우 실행 취소를 할 수 있습니다.
#
# 실행취소 단축키 (커멘드모드 + Z)

# %% [markdown]
# ### 셀의 타입 변경

# %% [markdown]
# **[셀 타입 변경 단축키]**
# 1. 코드 셀로 변경 (커멘드모드 + Y)
# 2. 마크다운 셀로 변경 (커멘드모드+ M)

# %% [markdown]
# print('안녕하세요')

# %% [markdown]
# ## 실행과 출력

# %% [markdown]
# * **셀**: 실행의 단위
# * **실행**: 재생 버튼을 클릭하여, 실행 (해당 셀 실행)
# * **실행 순서**: *인터프리터 방식* 으로 실행하며, 순차적으로 메모리에 기억합니다.

# %% [markdown]
# **[실행 관련 단축키]**
#
# 1. 해당 셀을 실행하고 커서는 해당 셀  (Ctrl + Enter)
# 2. 해당 셀을 실행하고 커서는 다음 셀  (Shift + Enter)
# 3. 해당 셀을 실행하고 커서는 다음에 셀 삽입  (Alt + Enter)

# %%
print('안녕하세요1')
# Out:
# 안녕하세요1

# %%
print('안녕하세요2')
# Out:
# 안녕하세요2

# %%
print('안녕하세요3')
# Out:
# 안녕하세요3

# %% [markdown]
# ## 혹시 단축키를 모른다면?

# %% [markdown]
# 커멘드모드 + H (키보드 단축키 보기)

# %% [markdown]
# Help - Keyboard Shortcuts를 클릭

# %% [markdown]
# ## 마크다운 문법의 이해

# %% [markdown]
# Markdown(마크다운)이란 Markup(마크업)언어의 일종으로, **HTML경험이 없는 사람도 누구나 쉽게** 헤더,글 머리 기호,이미지 삽입, 링크, 글자 모양 등 다양한 서식을 쉽게 추가하는 방식의 문서 편집 문법이다.

# %% [markdown]
# **[실습예제]**
# ## colab 이란?
# Google Colaboratory
#
# 구글에서 **교육과 과학 연구를 목적**으로 개발한 도구로, 2017년에 무료로 공개하였습니다.
#
# ### 장점
# 1. 무료
# 2. 구글 드라이브와 연동 가능
# 3. GPU를 사용할 수 있음
# 4. 깃헙(Github)에 있는 노트북 코드를 바로 돌려볼 수 있음
# 5. 손 쉽게 타인과 공유할 수 있음
#
#
# ### 단점
# 1. 90분동안 아무런 인터액션이 없거나 (idle timeout), 12시간의 ***세션 타임아웃***이 존재함
# 2. GPU는 할당을 못받을 수도 있음 (혹은 빼앗기는 경우도 있음)
# 3. 조금 느림

# %% [markdown]
# # 헤더
#
# 구글에서 교육과 **과학 연구**를 목적으로 개발한 도구로, 2017년에 무료로 공개하였습니다.
#
# 1. 순서1
# 2. 순서1
# 3. 순서1
#
#
# * 순서없다
# * 순서없다
# * 순서없다

# %% [markdown]
# ## 그 밖의 기능 - 이미지, Youtube 동영상 로딩하기

# %%
from IPython.display import Image

Image('https://www.python.org/static/community_logos/python-logo-master-v3-TM-flattened.png')

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('ACzFIAOsfpM', 600, 380)

# %%
from IPython.display import HTML

HTML('https://www.naver.co.kr/')
# Out:
# <!doctype html>                 <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 
# ...
